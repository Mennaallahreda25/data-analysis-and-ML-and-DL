# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd 
import io
import requests

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data"
s = requests.get(url).content
data = pd.read_table(io.StringIO(s.decode('utf-8')),sep=' ')
data
# Out:
#       Yr    Mo    Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7  \
# 0     61   NaN   1.0         NaN        1.00  15.04       14.96       13.17
# 1     61   NaN   1.0         NaN        2.00  14.71         NaN         NaN
# 2     61   NaN   1.0         NaN        3.00  18.50       16.88       12.33
# 3     61   NaN   1.0         NaN        4.00  10.58         NaN        6.63
# 4     61   NaN   1.0         NaN        5.00  13.33       13.25       11.42
# ...   ..   ...   ...         ...         ...    ...         ...         ...
# 6569  78  12.0  27.0       17.58       16.96  17.62         NaN        8.08
# 6570  78  12.0  28.0       13.21         NaN   5.46       13.46         NaN
# 6571  78  12.0  29.0       14.00       10.29  14.42         NaN        8.71
# 6572  78  12.0  30.0       18.50       14.04  21.29         NaN        9.13
# 6573  78  12.0  31.0       20.33       17.41  27.29         NaN        9.59
#
# ...

# %%
data["Dy"]= pd.to_datetime(data["Dy"])
data["Yr"]= pd.to_datetime(data["Yr"])
data["Mo"]= pd.to_datetime(data["Mo"])

data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 39 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Yr           6574 non-null   datetime64[ns]
#  1   Mo           1656 non-null   datetime64[ns]
#  2   Dy           6088 non-null   datetime64[ns]
#  3   Unnamed: 3   4743 non-null   float64
#  4   Unnamed: 4   4907 non-null   float64
#  5   RPT          4949 non-null   float64
#  6   Unnamed: 6   4318 non-null   float64
#  7   Unnamed: 7   4096 non-null   float64
#  8   VAL          4142 non-null   float64
#  9   Unnamed: 9   4473 non-null   float64
#  10  Unnamed: 10  3999 non-null   float64
#  11  ROS          4422 non-null   float64
#  12  Unnamed: 12  4181 non-null   float64
#  13  Unnamed: 13  4431 non-null   float64
#  14  KIL          4243 non-null   float64
#  15  Unnamed: 15  4353 non-null   float64
#  16  Unnamed: 16  3589 non-null   float64
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data
# Out:
#                                 Yr                            Mo  \
# 0    1970-01-01 00:00:00.000000061                           NaT
# 1    1970-01-01 00:00:00.000000061                           NaT
# 2    1970-01-01 00:00:00.000000061                           NaT
# 3    1970-01-01 00:00:00.000000061                           NaT
# 4    1970-01-01 00:00:00.000000061                           NaT
# ...                            ...                           ...
# 6569 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6570 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6571 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6572 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6573 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
#
#                                 Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  \
# 0    1970-01-01 00:00:00.000000001         NaN        1.00  15.04       14.96
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index("Dy","Yr","Mo" , inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19324\501688735.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   data.set_index("Dy","Yr","Mo" , inplace=True)

# %%
data
# Out:
#                                                               Yr  \
#      Dy
# 0    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 1    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 2    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 3    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 4    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# ...                                                          ...
# 6569 1970-01-01 00:00:00.000000027 1970-01-01 00:00:00.000000078
# 6570 1970-01-01 00:00:00.000000028 1970-01-01 00:00:00.000000078
# 6571 1970-01-01 00:00:00.000000029 1970-01-01 00:00:00.000000078
# 6572 1970-01-01 00:00:00.000000030 1970-01-01 00:00:00.000000078
# 6573 1970-01-01 00:00:00.000000031 1970-01-01 00:00:00.000000078
#
#                                                               Mo  Unnamed: 3  \
#      Dy
# 0    1970-01-01 00:00:00.000000001                           NaT         NaN
# ...

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna
# Out:
# <bound method DataFrame.isna of                                                               Yr  \
#      Dy
# 0    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 1    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 2    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 3    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# 4    1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000061
# ...                                                          ...
# 6569 1970-01-01 00:00:00.000000027 1970-01-01 00:00:00.000000078
# 6570 1970-01-01 00:00:00.000000028 1970-01-01 00:00:00.000000078
# 6571 1970-01-01 00:00:00.000000029 1970-01-01 00:00:00.000000078
# 6572 1970-01-01 00:00:00.000000030 1970-01-01 00:00:00.000000078
# 6573 1970-01-01 00:00:00.000000031 1970-01-01 00:00:00.000000078
#
#                                                               Mo  Unnamed: 3  \
#      Dy
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6574 entries, (0, Timestamp('1970-01-01 00:00:00.000000001')) to (6573, Timestamp('1970-01-01 00:00:00.000000031'))
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   
# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame({"the min": data.min(),
                       "the max": data.max(),
                       "the mean": data.mean(),
                       "standard deviations": data.std()}) 
loc_stats
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19324\3845694346.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   "the mean": data.mean(),
#                                    the min                        the max  \
# BEL                                    NaN                            NaN
# BIR                                    0.0                           35.5
# CLA                                   0.58                          26.25
# CLO                                    NaN                            NaN
# DUB                                   0.04                          34.08
# KIL                                    0.0                          42.38
# MAL                                    NaN                            NaN
# MUL                                    NaN                            NaN
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
data.columns
# Out:
# Index(['level_0', 'Dy', 'Yr', 'Mo', 'Unnamed: 3', 'Unnamed: 4', 'RPT',
#        'Unnamed: 6', 'Unnamed: 7', 'VAL', 'Unnamed: 9', 'Unnamed: 10', 'ROS',
#        'Unnamed: 12', 'Unnamed: 13', 'KIL', 'Unnamed: 15', 'Unnamed: 16',
#        'SHA', 'Unnamed: 18', 'Unnamed: 19', 'BIR', 'Unnamed: 21',
#        'Unnamed: 22', 'DUB', 'Unnamed: 24', 'Unnamed: 25', 'CLA',
#        'Unnamed: 27', 'Unnamed: 28', 'MUL', 'Unnamed: 30', 'Unnamed: 31',
#        'CLO', 'Unnamed: 33', 'Unnamed: 34', 'BEL', 'Unnamed: 36',
#        'Unnamed: 37', 'MAL'],
#       dtype='object')

# %%
newdf = data.drop(["Yr","Mo"], axis = 1) 
newdf.rename(columns = {'Dy':'date'}, inplace = True)
newdf
# Out:
#       level_0                          date  Unnamed: 3  Unnamed: 4    RPT  \
# 0           0 1970-01-01 00:00:00.000000001         NaN        1.00  15.04
# 1           1 1970-01-01 00:00:00.000000001         NaN        2.00  14.71
# 2           2 1970-01-01 00:00:00.000000001         NaN        3.00  18.50
# 3           3 1970-01-01 00:00:00.000000001         NaN        4.00  10.58
# 4           4 1970-01-01 00:00:00.000000001         NaN        5.00  13.33
# ...       ...                           ...         ...         ...    ...
# 6569     6569 1970-01-01 00:00:00.000000027       17.58       16.96  17.62
# 6570     6570 1970-01-01 00:00:00.000000028       13.21         NaN   5.46
# 6571     6571 1970-01-01 00:00:00.000000029       14.00       10.29  14.42
# 6572     6572 1970-01-01 00:00:00.000000030       18.50       14.04  21.29
# 6573     6573 1970-01-01 00:00:00.000000031       20.33       17.41  27.29
#
# ...

# %%
day_stats = pd.pivot_table(newdf, values =newdf.iloc[:,3:].describe(),index ='date',columns =['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])
day_stats
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
newdf.pivot_table(index=pd.Grouper(freq='M',key='date'),columns=['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
newdf.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns=['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
newdf.pivot_table(index=pd.Grouper(freq='M',key='date'),columns=['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
newdf.pivot_table(index=pd.Grouper(freq='W',key='date'),columns=['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
newdf.pivot_table(index=pd.Grouper(freq='W',key='date'),values=newdf.iloc[:,3:].describe(),columns=['RPT','VAL', 'ROS', 'KIL', 'SHA', 'BIR','DUB', 'CLA','MUL','CLO','BEL','MAL'])
